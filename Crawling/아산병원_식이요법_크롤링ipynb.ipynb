# %%
import requests
from bs4 import BeautifulSoup
import csv

# 웹 페이지에서 데이터 가져오기
url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 질병명과 본문 가져오기
disease_data = []

for disease in soup.find_all("dt"):
    disease_name = disease.find("a", class_="txtellipsis")
    disease_link = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do" + disease.find("a", class_="txtellipsis")["href"]

#     # 각 질병 페이지로 접속하여 본문 크롤링
#     disease_response = requests.get(disease_link).text
#     disease_soup = BeautifulSoup(disease_response, "html.parser")
#     disease_text = disease_soup.find("div", class_="info_contents").text.strip()
#     disease_data.append([disease_name, disease_text])

# # CSV 파일로 저장
# with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
#     writer = csv.writer(csvfile)
#     writer.writerow(["Disease Name", "Disease Text"])
#     writer.writerows(disease_data)

# print("CSV 파일이 성공적으로 생성되었습니다.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-1eb25fb36cc3> in <cell line: 13>()
#      13 for disease in soup.find_all("dt"):
#      14     disease_name = disease.find("a", class_="txtellipsis")
# ---> 15     disease_link = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do" + disease.find("a", class_="txtellipsis")["href"]
#      16
#      17 #     # 각 질병 페이지로 접속하여 본문 크롤링
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 질병명과 본문 가져오기
for disease in soup.find_all("dt"):
    disease_name = disease.find("a", class_="txtellipsis")
    if disease_name:
        disease_name = disease_name.text.strip()
# Out:
# Disease Name: 후천성면역결핍증식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=121
# Disease Name: 후두암식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=120
# Disease Name: 화상식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=119
# Disease Name: 호모시스틴뇨증식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=118
# Disease Name: 협심증식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=117
# Disease Name: 허혈성심장질환식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=116
# Disease Name: 항문암식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=115
# Disease Name: 프로피온산혈증, 프로피온산증
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=114
# Disease Name: 프라더 윌리 증후군식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=113
# Disease Name: 폐렴식
# Disease Link: https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do/asan/healthinfo/mealtherapy/mealTherapyDetail.do?mtId=112

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 질병명과 본문 가져오기
for disease in soup.find_all("dt"):
    disease_name = disease.find("a", class_="txtellipsis")
    if disease_name:
        disease_name = disease_name.text.strip()

        # 해당 질병의 링크가 있는 경우에만 처리
        disease_link_tag = disease.find("a", class_="txtellipsis")
        if disease_link_tag:
            disease_link = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do" + disease_link_tag["href"]

            # 질병의 링크로 접속하여 본문 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 식사요법 등의 본문 가져오기
            diet_therapy = disease_soup.find("div", class_="info_contents").text.strip()

            print("Disease Name:", disease_name)
            print("Dietary Therapy:", diet_therapy)
        else:
            print("Disease Name:", disease_name)
            print("No link available")
# Out:
# Disease Name: 후천성면역결핍증식
# Dietary Therapy: None
# Disease Name: 후두암식
# Dietary Therapy: None
# Disease Name: 화상식
# Dietary Therapy: None
# Disease Name: 호모시스틴뇨증식
# Dietary Therapy: None
# Disease Name: 협심증식
# Dietary Therapy: None
# Disease Name: 허혈성심장질환식
# Dietary Therapy: None
# Disease Name: 항문암식
# Dietary Therapy: None
# Disease Name: 프로피온산혈증, 프로피온산증
# Dietary Therapy: None
# Disease Name: 프라더 윌리 증후군식
# Dietary Therapy: None
# Disease Name: 폐렴식
# Dietary Therapy: None

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 질병명과 본문 가져오기
for disease in soup.find_all("dt"):
    disease_name = disease.find("a", class_="txtellipsis")
    if disease_name:
        disease_name = disease_name.text.strip()

        # 해당 질병의 링크가 있는 경우에만 처리
        disease_link_tag = disease.find("a", class_="txtellipsis")
        if disease_link_tag:
            disease_link = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do" + disease_link_tag["href"]

            # 질병의 링크로 접속하여 본문 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 식사요법 등의 본문 가져오기
            diet_therapy_tag = disease_soup.select_one(".info_contents")
            diet_therapy = diet_therapy_tag.text.strip() if diet_therapy_tag else "No dietary therapy available"

            print("Disease Name:", disease_name)
            print("Dietary Therapy:", diet_therapy)
        else:
            print("Disease Name:", disease_name)
            print("No link available")
# Out:
# Disease Name: 후천성면역결핍증식
# Dietary Therapy: No dietary therapy available
# Disease Name: 후두암식
# Dietary Therapy: No dietary therapy available
# Disease Name: 화상식
# Dietary Therapy: No dietary therapy available
# Disease Name: 호모시스틴뇨증식
# Dietary Therapy: No dietary therapy available
# Disease Name: 협심증식
# Dietary Therapy: No dietary therapy available
# Disease Name: 허혈성심장질환식
# Dietary Therapy: No dietary therapy available
# Disease Name: 항문암식
# Dietary Therapy: No dietary therapy available
# Disease Name: 프로피온산혈증, 프로피온산증
# Dietary Therapy: No dietary therapy available
# Disease Name: 프라더 윌리 증후군식
# Dietary Therapy: No dietary therapy available
# Disease Name: 폐렴식
# Dietary Therapy: No dietary therapy available

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyDetail.do?pageIndex=1&searchCondition=&searchKeyword=&mtId=121"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 본문 가져오기
content = soup.find("dl", class_="descDl")
if content:
    diet_therapy = content.text.strip()
    print("Dietary Therapy:", diet_therapy)
else:
    print("No content available")
# Out:
# Dietary Therapy: 식사요법의 필요성
# 필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 나타날 때 식사를 변형, 수정하여 영양불량상태를 예방하거나 지연시키기 위해 식사조절이 필요합니다.
#
# 식사요법의 실제
# 1. 균형잡힌 식사를 합니다.
# 2. 단백질 식품을 충분히 섭취합니다.
# 3. 충분한 수분을 섭취합니다.
# 4. 비타민제 섭취 시에는 과잉 섭취되지 않도록 주의합니다.
#
# 권장 식품
# 양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달지 않은 식품
#
# 주의 식품
# 과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진 국물류, 가공식품, 인스턴트 식품(라면, 햄버거 등)
#
# 그 외 주의사항
# 흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.
#
# 추천 식단

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("dl", class_="descDl")
        if diet_therapy_tag:
            diet_therapy = diet_therapy_tag.text.strip()
        else:
            diet_therapy = "No dietary therapy available"

        print("Disease Name:", disease_name)
        print("Dietary Therapy:", diet_therapy)
# Out:
# Disease Name: 후천성면역결핍증식
# Dietary Therapy: 식사요법의 필요성
# 필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 나타날 때 식사를 변형, 수정하여 영양불량상태를 예방하거나 지연시키기 위해 식사조절이 필요합니다.
#
# 식사요법의 실제
# 1. 균형잡힌 식사를 합니다.
# 2. 단백질 식품을 충분히 섭취합니다.
# 3. 충분한 수분을 섭취합니다.
# 4. 비타민제 섭취 시에는 과잉 섭취되지 않도록 주의합니다.
#
# 권장 식품
# 양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달지 않은 식품
#
# 주의 식품
# 과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진 국물류, 가공식품, 인스턴트 식품(라면, 햄버거 등)
#
# 그 외 주의사항
# 흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.
#
# 추천 식단
# Disease Name: 후두암식
# Dietary Therapy: 식사요법의 필요성
# 후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 최소화 하기위해 식사요법이 필요합니다.
# 후두암의 치료는 병기나 종류에 따라 다르며 크게 수술적치료, 항암치료, 방사선치료 등이 사용됩니다. 따라서 각 치료방법을 이해하고 치료에 따르는 부작용으로 인한 영양문제의 대처방법을 숙지하여 영양불량이 되지않도록 합니다.
#
#
# 식사요법의 실제
# 암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지하는것이 중요합니다. 그러기 위해서는 충분한 에너지와 단백질, 비타민 및 무기질을 공급할 수 있는 식사를 섭취해야 하며, 이는 여러가지 음식을 골고루 먹음으로써 가능합니다.
# 암환자의 일반적인 식사지침
# 1. 아침,점심,저녁을 규칙적으로 섭취하고 반찬은 골고루 먹습니다.
# 2. 매끼 단백질 반찬을 꼭 먹습니다.(고기, 생선이 싫다면 대신 달걀, 두부, 콩, 치즈 등을 먹습니다.)
# 3. 채소반찬은 매끼 2가지 이상 충분히 먹습니다.(씹기 힘든 경우나 삼키기 힘든 경우에는 다지거나 갈아서 먹습니다.)
# 4. 과일은 하루 1~2번, 1가지 이상 먹습니다.(면역력이 저하된 경우 잘 씻어 껍질을 제거하거나 통조림, 주스로 먹습니다.)
# 5. 유제품을 하루 1컵 마십니다.(우유가 맞지 않을 경우에는 요쿠르트, 두유, 치즈, 아이스크림으로 대체합니다.)
# 6. 밥은 매끼 1그릇정도 먹습니다.(밥 섭취가 어려울 경우 죽, 빵, 크래커, 떡, 감자, 고구마, 국수, 미숫가루 등으로 대체하며, 밥 섭취량이 적을 경우에는 간식으로 보충합니다.)
# 7. 열량보충이 필요하다면 식물성 기름과 견과류를 충분히 사용합니다.
# 8. 양념과 조미료는 적당히 사용합니다.
#
# 권장 식품
# 현미, 보리, 서리태와 같은 잡곡 및 두류
# 파프리카, 당근, 단호박, 양배추, 케일, 가지등의 다양한 색의 채소, 과일류
#
# 주의 식품
# 술, 비위생적인 식품, 가공식품, 탄 음식
#
# 그 외 주의사항
# 환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문가와 상의합니다.
# 항암-방사선 병용요법으로 치료를 받은경우 충분한 열량과 단백질(고기, 생선, 콩, 두부, 계란, 해물)을 섭취하여 체중이 감소되지 않도록 주의하며 필요에 따라 상업용 영양보충음료를 병행하도록 합니다. 절대적으로 금연합니다.
#
# 추천 식단
# Disease Name: 화상식
# Dietary Therapy: 식사요법의 필요성
# 화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체액의 손실이 증가하여 수분 및 전해질의 불균형을 초래할 수 있어 충분한 열량과 단백질 공급이 필요합니다
#
# 식사요법의 실제
# 1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.
# 2. 식사를 규칙적으로 하며 편식하지 말고 골고루 섭취합니다.
# 3. 질이 좋은 단백질 식품(고기, 생선, 두부 등)을 끼마다 충분히 섭취합니다.
# 4. 신선한 채소 및 과일을 충분히 섭취합니다.
# 5. 지나치게 단 음식은 피합니다.
# 6. 수분을 충분히 섭취합니다.(2L/day)
#
# 권장 식품
# 곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 등), 두부, 콩, 달걀, 신선한 채소, 견과류(땅콩, 호두, 잣 등), 신선한 과일, 유제품(우유, 두유, 요구르트, 요거트, 저지방우유)
#
# 주의 식품
#  단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과일,  주류(소주, 맥주, 막걸리 등)
#
# 그 외 주의사항
# 1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 보충합니다.
# 2. 대사적 스트레스로 인한 고혈당을 악화시킬 수 있어 과다한 단음식은 피합니다.
#
# 추천 식단
# Disease Name: 호모시스틴뇨증식
# Dietary Therapy: 식사요법의 필요성
# 호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 여러가지 합병증을 예방하고, 정상적인 성장과 발달을 도모하기 위해 식사요법이 필요합니다.
#
# 식사요법의 실제
# 1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분유를 혼합하여 수유합니다.
# 2. 분유량은 반드시 정확하게 계량하여 먹입니다.
# 3. 성장에 따라 영양 요구량이 달라지므로 주기적으로 영양상담을 받도록 합니다.
#
# 권장 식품
# 곡류, 채소류, 과일류, 식물성 기름
#
# 주의 식품
# 콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
#
# 그 외 주의사항
# 처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연 등의 결과를 초래할 수 있습니다.
# Disease Name: 협심증식
# Dietary Therapy: 식사요법의 필요성
# 협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받는 상태로 심한 가슴통증을 유발하게 됩니다. 주된 원인은 혈관 속의 지방 축적이므로 정상 체중을 유지하고 비만인 경우는 체중을 감소시키는 것이 꼭 필요합니다.
#
# 식사요법의 실제
# 1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. 단, 입맛에 맞지 않을 경우 무리하게 잡곡밥을 고집하지 말고 쌀밥을 섭취합니다.
# 2. 고기, 두부, 생선 등의 단백질 반찬도 골고루 섭취하되 고기는 기름기와 껍질을 제거한 살코기로 섭취합니다.
# 3. 채소찬은 제철 채소를 이용하여 싱겁게 조리하되 장아찌, 김치 등의 염장식품은 지양합니다.
# 4. 간식은 정규 식사 사이에 제철 과일과 우유로 섭취합니다.
# 5. 전체적인 조리 방법은 지방 섭취를 줄이기 위해 튀기거나 부치는 대신 굽기, 찜, 삶는 방법을 주로 선택하나 맛을 내기 위해 적당량의 식물성기름(참기름, 들기름 등)은 사용합니다.
# 6. 또한 염분량은 소금을 기준으로 1일 6g만 추가하도록 합니다.
# 7. 저염식 적응을 위해 조리 시 미리 염분을 넣는 것보다 무염 조리 후 따로 분량의 저염 소스를 곁들이는 것이 더욱 효과적입니다.
#
# 권장 식품
# 신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 등 균형잡힌 식사
#
# 주의 식품
# 고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류
# 고콜레스테롤 식품 : 내장류, 새우, 오징어, 계란노른자
# 기름진 음식 : 탕류, 중국음식, 튀김류, 전류
# 염장 식품 : 김치류, 젓갈류, 장아찌류, 건어물 및 자반 생선류
# 가공식품 : 햄류, 통조림류, 라면
# 국물류 : 국, 찌개
#
# 그 외 주의사항
# 소량씩 자주 먹습니다.
# 상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한합니다.
# 섬유소 섭취를 점차로 증가시키며 이때 수분도 부족하지 않게 섭취합니다.
# 카페인 섭취를 줄입니다.
# 과체중인 경우 열량제한식을 병행합니다.
#
#
# 추천 식단
# Disease Name: 허혈성심장질환식
# Dietary Therapy: 식사요법의 필요성
# 심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다.
# [콜레스테롤에 대한 식사요법]
# 혈액내 콜레스테롤의 ⅔ ~ ¾ 정도는 몸 안에서 형성된 것으로 식사를 변화시킴으로써 감소시킬 수 있습니다. 보통 콜레스테롤의 1일 섭취량을 100㎎ 이하로 줄이는 경우에는 현저한 콜레스테롤의 감소가 생기지만 사실상 실천이 불가능하며, 1일 섭취량을 300㎎정도로 유지하면 혈액내의 콜레스테롤 양이 10%정도 감소합니다.
# 콜레스테롤은 주로 계란노른자, 오징어, 새우 그리고 기름진 생선 등에 많으며 육류의 기름에도 많이 함유되어 있습니다. 따라서 콜레스테롤 수치가 높을 경우 월 2~3회 정도로 고콜레스테롤 함유 식품 섭취를 줄이고 육류 섭취 시 껍질과 기름기를 제거한 살코기로 섭취해야 합니다.
# [저염식]
# 보통 한국인은 1일 20g 이상의 소금을 섭취하나 실제로 꼭 필요한 양은 5g 이하이므로 고혈압 치료를 목표로 할 때는 소금의 섭취를 절대적으로 줄여야 합니다.
# 실제로 소금의 섭취를 줄이는 방법은 식성을 변화시키고자 하는 노력이 중요합니다. 조리를 할 때 차츰 차츰 첨가되는 소금을 줄이고 소금 성분이 많은 양념이나 조미료 등도 주의해야 합니다. 그리고 한국인 식습관의 특징인 국이나 찌개 국물 그리고 염장식품 섭취를 지양함으로써 소금 섭취를 줄이는 것이 중요합니다.
# [비만의 개선을 위한 식사요법]
# 체중이 증가한다는 것은 소모 열량보다 섭취 열량이 과다하다는 것을 의미합니다. 이상적인 체중 감량은 1달에 2㎏ 정도 감량하는 것인데 이를 위해서는 하루에 500kcal씩 적게 먹든지, 아니면 500kcal씩 더 열량을 소비해야 가능합니다.
# 하지만 섭취량에는 식사 뿐 아니라 간식이나 술의 영향이 더욱 큰 문제가 될 수 있으며 식사 감량만으로는 체중 감소의 속도가 떨어지거나 다시 체중이 증가될 수 있으므로, 운동을 병행하는 것이 더욱 효과적입니다. 따라서 체중 감소 시 전문가와의 상담을 통해 실천하는 것이 중요합니다.
#
# 식사요법의 실제
# 1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. 단, 입맛에 맞지 않을 경우 무리하게 잡곡밥을 고집하지 말고 쌀밥을 섭취합니다.
# 2. 고기, 두부, 생선 등의 단백질 반찬도 골고루 섭취하되 고기는 기름기와 껍질을 제거한 살코기로 섭취합니다.
# 3. 채소찬은 제철 채소를 이용하여 싱겁게 조리하되 장아찌, 김치 등의 염장식품은 지양합니다.
# 4. 간식은 정규 식사 사이에 제철 과일과 우유로 섭취합니다.
# 5. 전체적인 조리 방법은 지방 섭취를 줄이기 위해 튀기거나 부치는 대신 굽기, 찜, 삶는 방법을 주로 선택하나 맛을 내기 위해 적당량의 식물성기름(참기름, 들기름 등)은 사용합니다.
# 6. 저염식 적응을 위해 조리 시 미리 염분을 넣는 것보다 무염 조리 후 따로 분량의 저염 소스를 곁들이는 것이 더욱 효과적입니다.
# 7. 콜레스테롤이 높은 식품은 월 2~3회로 줄여서 섭취합니다.
#
# 권장 식품
# 신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 등 균형잡힌 식사
#
# 주의 식품
# 고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류
# 고콜레스테롤 식품 : 내장류, 새우, 오징어, 계란노른자
# 기름진 음식 : 탕류, 중국음식, 튀김류, 전류
# 염장 식품 - 김치류, 젓갈류, 장아찌류, 건어물 및 자반 생선류
# 가공식품 - 햄류, 통조림류, 라면
# 국, 찌개 국물류
#
# 그 외 주의사항
# 오메가-3 지방산은 에이코사펜타엔산(EPA), 도코사헥사엔산(DHA) 등으로 주로 생선기름에 많이 포함되어 있습니다.
# 생선을 많이 먹는 알래스카 원주민에서 심혈관계 질환의 사망률이 낮은 것이 관찰되었고 이후 오메가-3의 효능에 대한 많은 연구들에서 오메가-3가 심혈관계 사망률을 낮춘다는 결과를 보고하였습니다. 오메가-3는 혈소판 응집과 염증반응을 감소시키고, 혈중 중성지방의 농도를 감소시키고, 심박수와 혈압을 강하시켜 심혈관계 질환으로 인한 사망을 감소시키는 것으로 생각되고 있습니다.
#
#
# 추천 식단
# Disease Name: 항문암식
# Dietary Therapy: 식사요법의 필요성
# 수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며, 수술 후 약 6주 정도 섬유질 섭취를 줄여 대변 양 조절과 폐색 등의 위험을 최소화 합니다.
#
# 식사요법의 실제
# 1. 고섬유질 식품 섭취를 줄입니다. (잡곡류, 채소 및 해조류, 과일류, 견과류 등)
# 2. 양질의 단백질 식품을 충분히 섭취합니다.
# 3. 자극성이 강한 향신료나 조미료는 피합니다.
# 4. 충분한 수분섭취를 합니다.(kg당 30cc)
#
# 권장 식품
# 수술직후 : 쌀밥, 흰국수, 생선, 계란, 두부, 육류(결체조직 및 껍질 제외), 유제품
#
# 주의 식품
# 수술직후 : 잡곡, 질긴 채소, 건조 과일과 껍질, 씨앗, 견과류, 자극성 식품
#
# 그 외 주의사항
# 1. 수술 직후 약 6주간 고섬유식품 섭취를 줄이도록 합니다.
# 2. 수술 부위, 장루의 유무에 따른 식사요법이 필요합니다. (저잔사식)
# 3. 수술 후 2달뒤 정상식사 시 충분한 섬유소 섭취가 권장됩니다.
#
# 추천 식단
# Disease Name: 프로피온산혈증, 프로피온산증
# Dietary Therapy: 식사요법의 필요성
# 발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에 관여하는 propionyl CoA carboxylase라는 효소의 장애로 프로피오닌산이 축적되어 뇌손상, 혈액의 산성화, 암모니아의 증가 등을 초래합니다. 상염색체열성유전을 하며 발생빈도는 100,000명중 한 명입니다. 장기적으로는 고탄수화물 식이와, 이소로이신, 발린, 메치오닌, 스레오닌이라는 아미노산을 작은 양으로 제한한 식이를 합니다. 이들 아미노산이 없는 특수분유제제와 일반식이를 혼합하여 식이요법을 합니다.
#
#
# 식사요법의 실제
# 1. 루이신, 이소루이신, 발린, 메티오닌, 트레오닌 등 프로피온산의 전구물질이 될 수 있는 아미노산을 제거한 특수분유를 사용합니다.
# 2. 국내에서 생산되는 특수분유는 MPA 1 과 2가 있으며 MPA 2는 1에 비해 열량이 적은 대신 단백질 함량이 두배이고, 다른 영양소들은 비슷하게 함유하고 있어 식사량이 충분한 소아청소년기에 처방하기에 적절합니다.
# 3. 발린이 가장 중요한 아미노산이므로 발린의 섭취를 기준으로 식이요법을 실시하며, 다른 아미노산들은 적당한 비율로 조절합니다. 제한되는 아미노산들은 필수 아미노산이므로 분유만 섭취하는 영아의 경우, 반드시 일반분유를 특수분유와 함께 처방받아 먹여야 필수 아미노산 결핍증을 막을 수 있습니다.
# 4. 아이가 나이가 들면서 식사를 잘하게 되면 일반분유는 필요하지 않게 되며, MPA 2 분유로 바꾸어 먹을 수 있습니다.         5. 후기 발병형의 환자들은 아미노산의 투여를 잘 견딜 수 있고, 발린의 섭취까지 계산하지 않고 단백질의 섭취량을 계산하는 정도로도 치료할 수 있으므로 훨씬 쉽다고 할 수 있습니다.
#
# 권장 식품
# 쌀, 고구마, 감자 등 탄수화물 식품과 식물성 기름, 버터류, 모든 채소와 과일류
#
# 주의 식품
# 쇠고기, 돼지고기, 닭고기, 생선 및 가공품, 우유 및 유제품 등 발린 함량이 높은 식품들
#
# 그 외 주의사항
# 여러가지 감염, 예방접종, 외상, 마취 및 수술과 같은 상황이 발생하면 단백질 섭취를 제한하고 탄수화물 섭취를 늘리는 것이 필요합니다. 이러한 상황들의 일부는 예측이 가능하며, 환자의 질병 종류와 대사 상태에 따라서 식이요법을 조정할 필요가 있습니다. 하지만 감염과 같은 경우는 예측이 불가능하며 따라서 악화되지 않도록 미리 예방하는 것이 어렵습니다. 미리 예방하기 위해 지속적으로 단백질을 더 제한한다면 만성 영양결핍과 대사의 불균형 상태를 초래할 수 있으므로 단백질의 과다한 투여를 피하고, 단백질의 분해와 대사의 불균형이 초래될 수 있는 상황을 빨리 알 수 있도록 보호자는 지속적으로 교육을 받아야 합니다.
# Disease Name: 프라더 윌리 증후군식
# Dietary Therapy: 식사요법의 필요성
# 비만으로 인한 합병증을 조절하기 위해 필요합니다.
#
# 식사요법의 실제
# 1. 보통의 비만아보다 더 강하게 열량을 제한합니다.
# 2. 당뇨가 동반된 경우 당뇨 식사요법의 기준에 따릅니다.
# 3. 고지혈증, 고혈압이 있을 경우 저열량 조리법을 이용한 음식을 주로 섭취하고, 싱겁게 먹습니다.
# 4. 규칙적으로 운동합니다.
#
# 권장 식품
# 잡곡밥, 신선한 채소와 과일(당뇨가 있는 경우는 별도의 양 조절 필요), 해조류, 콩 및 두부류
#
# 주의 식품
# 사탕이나 초컬렛, 청량음료, 단 빵류 (케익 포함) 와 같이 단순당 또는 단순당이 포함된 음식, 치킨이나 도우넛, 팝콘 등 기름에 튀기거나 볶은 음식, 삼겹살, 갈비류, 소시지, 햄버거, 햄, 베이컨 등 고지방 식품은 최대한 먹지 않아야 합니다.
#
# 그 외 주의사항
# 기름지지 않은 음식이라 하더라도 식욕만큼 배를 채우게 되면 체중이 쉽게 늘어나므로 전체 섭취량을 조절하는 것이 중요합니다.
#
# 추천 식단
# Disease Name: 폐렴식
# Dietary Therapy: 식사요법의 필요성
# 증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방지하기 위하여 충분한 에너지와 단백질의 섭취가 매우 중요합니다.
#
# 식사요법의 실제
# 1. 과식보다는 간식과 함께 소량씩 자주 섭취합니다.
# 2. 매끼 양질의 어육류나 두부, 계란등을 챙겨서 섭취합니다.
# 3. 숨이 찰때는 부드러운 식품을 이용하여 합니다.
# 4. 수분을 소량씩 자주 보충합니다.
#
# 권장 식품
# 부드러운 살코기, 생선, 요구르트, 다양한 색상의 과일이나 채소
#
# 주의 식품
# 튀김, 육류의 기름
#
# 그 외 주의사항
# 잦은 가래 배출로 몸에 수분이 부족하기 쉬우므로 수시로 과일쥬스나 물 등으로 보충하도록 합니다.
#
# 추천 식단

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("dl", class_="descDl")
        if diet_therapy_tag:
            diet_therapy = diet_therapy_tag.text.strip()
        else:
            diet_therapy = "No dietary therapy available"

        # 결과를 리스트에 추가
        data.append([disease_name, diet_therapy])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["Disease Name", "Dietary Therapy"])
    writer.writerows(data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name                                    Dietary Therapy
# 0        후천성면역결핍증식  식사요법의 필요성\n필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적...
# 1             후두암식  식사요법의 필요성\n후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치...
# 2              화상식  식사요법의 필요성\n화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증...
# 3         호모시스틴뇨증식  식사요법의 필요성\n호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로...
# 4             협심증식  식사요법의 필요성\n협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적...
# 5         허혈성심장질환식  식사요법의 필요성\n심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다...
# 6             항문암식  식사요법의 필요성\n수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며,...
# 7  프로피온산혈증, 프로피온산증  식사요법의 필요성\n발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에...
# 8      프라더 윌리 증후군식  식사요법의 필요성\n비만으로 인한 합병증을 조절하기 위해 필요합니다.\n\n식사요법...
# 9              폐렴식  식사요법의 필요성\n증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방...
# No charts were generated by quickchart

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("dl", class_="descDl")
        if diet_therapy_tag:
            diet_therapy = diet_therapy_tag.text.strip()
        else:
            diet_therapy = "No dietary therapy available"

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, "Dietary Therapy": diet_therapy})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "Dietary Therapy"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name                                    Dietary Therapy
# 0        후천성면역결핍증식  식사요법의 필요성\n필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적...
# 1             후두암식  식사요법의 필요성\n후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치...
# 2              화상식  식사요법의 필요성\n화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증...
# 3         호모시스틴뇨증식  식사요법의 필요성\n호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로...
# 4             협심증식  식사요법의 필요성\n협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적...
# 5         허혈성심장질환식  식사요법의 필요성\n심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다...
# 6             항문암식  식사요법의 필요성\n수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며,...
# 7  프로피온산혈증, 프로피온산증  식사요법의 필요성\n발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에...
# 8      프라더 윌리 증후군식  식사요법의 필요성\n비만으로 인한 합병증을 조절하기 위해 필요합니다.\n\n식사요법...
# 9              폐렴식  식사요법의 필요성\n증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방...

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 특정한 명칭의 칼럼 추출
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            dietary_therapy_need = diet_therapy_tag.find("dt", text="식사요법의 필요성").find_next_sibling("dd").text.strip()
        else:
            dietary_therapy_need = "No information available"

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, "Dietary Therapy Need": dietary_therapy_need})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "Dietary Therapy Need"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name      Dietary Therapy Need
# 0        후천성면역결핍증식  No information available
# 1             후두암식  No information available
# 2              화상식  No information available
# 3         호모시스틴뇨증식  No information available
# 4             협심증식  No information available
# 5         허혈성심장질환식  No information available
# 6             항문암식  No information available
# 7  프로피온산혈증, 프로피온산증  No information available
# 8      프라더 윌리 증후군식  No information available
# 9              폐렴식  No information available

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 각 항목의 제목과 내용 추출
        dietary_therapy = {}
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            for dt_tag in diet_therapy_tag.find_all("dt"):
                title = dt_tag.text.strip()
                content = dt_tag.find_next_sibling("dd").text.strip()
                dietary_therapy[title] = content
        else:
            dietary_therapy = {"No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "식사요법의 필요성", "식사요법의 실제", "권장식품", "주의식품", "그 외 주의사항", "추천 식단"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-21ec6ab22352> in <cell line: 13>()
#      33
#      34         # 결과를 리스트에 추가
# ---> 35         data.append({"Disease Name": disease_name, **dietary_therapy})
#      36
#      37 # CSV 파일에 결과 저장
#
# TypeError: 'set' object is not a mapping

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 각 항목의 제목과 내용 추출
        dietary_therapy = {}
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            for dt_tag in diet_therapy_tag.find_all("dt"):
                title = dt_tag.text.strip()
                content = dt_tag.find_next_sibling("dd").text.strip()
                dietary_therapy[title] = content
        else:
            dietary_therapy = {"식사요법의 필요성": "No information available", "식사요법의 실제": "No information available",
                               "권장식품": "No information available", "주의식품": "No information available",
                               "그 외 주의사항": "No information available", "추천 식단": "No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "식사요법의 필요성", "식사요법의 실제", "권장식품", "주의식품", "그 외 주의사항", "추천 식단"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name                 식사요법의 필요성                  식사요법의 실제  \
# 0        후천성면역결핍증식  No information available  No information available
# 1             후두암식  No information available  No information available
# 2              화상식  No information available  No information available
# 3         호모시스틴뇨증식  No information available  No information available
# 4             협심증식  No information available  No information available
# 5         허혈성심장질환식  No information available  No information available
# 6             항문암식  No information available  No information available
# 7  프로피온산혈증, 프로피온산증  No information available  No information available
# 8      프라더 윌리 증후군식  No information available  No information available
# 9              폐렴식  No information available  No information available
#
#                        권장식품                      주의식품  \
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available
#
#                    그 외 주의사항                     추천 식단
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 각 항목의 제목과 내용 추출
        dietary_therapy = {}
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            dt_tags = diet_therapy_tag.find_all("dt")
            for dt_tag in dt_tags:
                title = dt_tag.text.strip()
                content = dt_tag.find_next_sibling("dd").text.strip()
                dietary_therapy[title] = content
        else:
            dietary_therapy = {"식사요법의 필요성": "No information available", "식사요법의 실제": "No information available",
                               "권장식품": "No information available", "주의식품": "No information available",
                               "그 외 주의사항": "No information available", "추천 식단": "No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "식사요법의 필요성", "식사요법의 실제", "권장식품", "주의식품", "그 외 주의사항", "추천 식단"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name                 식사요법의 필요성                  식사요법의 실제  \
# 0        후천성면역결핍증식  No information available  No information available
# 1             후두암식  No information available  No information available
# 2              화상식  No information available  No information available
# 3         호모시스틴뇨증식  No information available  No information available
# 4             협심증식  No information available  No information available
# 5         허혈성심장질환식  No information available  No information available
# 6             항문암식  No information available  No information available
# 7  프로피온산혈증, 프로피온산증  No information available  No information available
# 8      프라더 윌리 증후군식  No information available  No information available
# 9              폐렴식  No information available  No information available
#
#                        권장식품                      주의식품  \
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available
#
#                    그 외 주의사항                     추천 식단
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 각 항목의 제목과 내용 추출
        dietary_therapy = {}
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            dt_tags = diet_therapy_tag.find_all("dt")
            for dt_tag in dt_tags:
                title = dt_tag.text.strip()
                content = dt_tag.find_next_sibling("dd").text.strip()
                dietary_therapy[title] = content
        else:
            dietary_therapy = {"식사요법의 필요성": "No information available", "식사요법의 실제": "No information available",
                               "권장식품": "No information available", "주의식품": "No information available",
                               "그 외 주의사항": "No information available", "추천 식단": "No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "식사요법의 필요성", "식사요법의 실제", "권장식품", "주의식품", "그 외 주의사항", "추천 식단"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name                 식사요법의 필요성                  식사요법의 실제  \
# 0        후천성면역결핍증식  No information available  No information available
# 1             후두암식  No information available  No information available
# 2              화상식  No information available  No information available
# 3         호모시스틴뇨증식  No information available  No information available
# 4             협심증식  No information available  No information available
# 5         허혈성심장질환식  No information available  No information available
# 6             항문암식  No information available  No information available
# 7  프로피온산혈증, 프로피온산증  No information available  No information available
# 8      프라더 윌리 증후군식  No information available  No information available
# 9              폐렴식  No information available  No information available
#
#                        권장식품                      주의식품  \
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available
#
#                    그 외 주의사항                     추천 식단
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 각 항목의 제목과 내용 추출
        dietary_therapy = {}
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            dt_tags = diet_therapy_tag.find_all("dt")
            for dt_tag in dt_tags:
                title = dt_tag.text.strip()
                content = dt_tag.find_next_sibling("dd").text.strip()
                dietary_therapy[title] = content
        else:
            dietary_therapy = {"식사요법의 필요성": "No information available", "식사요법의 실제": "No information available",
                               "권장식품": "No information available", "주의식품": "No information available",
                               "그 외 주의사항": "No information available", "추천 식단": "No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# 각 항목별로 내용을 분리하여 따로 저장
for item in data:
    dietary_therapy_need = item.pop("식사요법의 필요성", "No information available")
    dietary_therapy_actual = item.pop("식사요법의 실제", "No information available")
    recommended_food = item.pop("권장식품", "No information available")
    caution_food = item.pop("주의식품", "No information available")
    other_caution = item.pop("그 외 주의사항", "No information available")
    recommended_menu = item.pop("추천 식단", "No information available")

    item["Dietary Therapy Need"] = dietary_therapy_need
    item["Dietary Therapy Actual"] = dietary_therapy_actual
    item["Recommended Food"] = recommended_food
    item["Caution Food"] = caution_food
    item["Other Caution"] = other_caution
    item["Recommended Menu"] = recommended_menu

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "Dietary Therapy Need", "Dietary Therapy Actual", "Recommended Food", "Caution Food", "Other Caution", "Recommended Menu"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name      Dietary Therapy Need    Dietary Therapy Actual  \
# 0        후천성면역결핍증식  No information available  No information available
# 1             후두암식  No information available  No information available
# 2              화상식  No information available  No information available
# 3         호모시스틴뇨증식  No information available  No information available
# 4             협심증식  No information available  No information available
# 5         허혈성심장질환식  No information available  No information available
# 6             항문암식  No information available  No information available
# 7  프로피온산혈증, 프로피온산증  No information available  No information available
# 8      프라더 윌리 증후군식  No information available  No information available
# 9              폐렴식  No information available  No information available
#
#            Recommended Food              Caution Food  \
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available
#
#               Other Caution          Recommended Menu
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 각 항목의 제목과 내용 추출
        dietary_therapy = {}
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            dt_tags = diet_therapy_tag.find_all("dt")
            for dt_tag in dt_tags:
                title = dt_tag.text.strip()
                content = dt_tag.find_next_sibling("dd").text.strip()
                dietary_therapy[title] = content
        else:
            dietary_therapy = {"식사요법의 필요성": "No information available", "식사요법의 실제": "No information available",
                               "권장식품": "No information available", "주의식품": "No information available",
                               "그 외 주의사항": "No information available", "추천 식단": "No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# 각 항목별로 내용을 분리하여 따로 저장
for item in data:
    dietary_therapy_need = item.pop("식사요법의 필요성", "No information available")
    dietary_therapy_actual = item.pop("식사요법의 실제", "No information available")
    recommended_food = item.pop("권장식품", "No information available")
    caution_food = item.pop("주의식품", "No information available")
    other_caution = item.pop("그 외 주의사항", "No information available")
    recommended_menu = item.pop("추천 식단", "No information available")

    item["Dietary Therapy Need"] = dietary_therapy_need
    item["Dietary Therapy Actual"] = dietary_therapy_actual
    item["Recommended Food"] = recommended_food
    item["Caution Food"] = caution_food
    item["Other Caution"] = other_caution
    item["Recommended Menu"] = recommended_menu

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "Dietary Therapy Need", "Dietary Therapy Actual", "Recommended Food", "Caution Food", "Other Caution", "Recommended Menu"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name      Dietary Therapy Need    Dietary Therapy Actual  \
# 0        후천성면역결핍증식  No information available  No information available
# 1             후두암식  No information available  No information available
# 2              화상식  No information available  No information available
# 3         호모시스틴뇨증식  No information available  No information available
# 4             협심증식  No information available  No information available
# 5         허혈성심장질환식  No information available  No information available
# 6             항문암식  No information available  No information available
# 7  프로피온산혈증, 프로피온산증  No information available  No information available
# 8      프라더 윌리 증후군식  No information available  No information available
# 9              폐렴식  No information available  No information available
#
#            Recommended Food              Caution Food  \
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available
#
#               Other Caution          Recommended Menu
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 각 항목의 제목과 내용 추출
        dietary_therapy = {}
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            for dt_tag in diet_therapy_tag.find_all("dt"):
                title = dt_tag.text.strip()
                content = dt_tag.find_next_sibling("dd").text.strip()
                dietary_therapy[title] = content
        else:
            dietary_therapy = {"식사요법의 필요성": "No information available",
                               "식사요법의 실제": "No information available",
                               "권장식품": "No information available",
                               "주의식품": "No information available",
                               "그 외 주의사항": "No information available",
                               "추천 식단": "No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "식사요법의 필요성", "식사요법의 실제", "권장식품", "주의식품", "그 외 주의사항", "추천 식단"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 각 항목의 제목과 내용 추출
        dietary_therapy = {}
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            content = diet_therapy_tag.get_text(separator="\n")
            content_sections = content.split("\n")
            for section in content_sections:
                if section.strip() == "":
                    continue
                title, text = section.split(":", 1)
                dietary_therapy[title.strip()] = text.strip()
        else:
            dietary_therapy = {"식사요법의 필요성": "No information available",
                               "식사요법의 실제": "No information available",
                               "권장식품": "No information available",
                               "주의식품": "No information available",
                               "그 외 주의사항": "No information available",
                               "추천 식단": "No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "식사요법의 필요성", "식사요법의 실제", "권장식품", "주의식품", "그 외 주의사항", "추천 식단"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name                 식사요법의 필요성                  식사요법의 실제  \
# 0        후천성면역결핍증식  No information available  No information available
# 1             후두암식  No information available  No information available
# 2              화상식  No information available  No information available
# 3         호모시스틴뇨증식  No information available  No information available
# 4             협심증식  No information available  No information available
# 5         허혈성심장질환식  No information available  No information available
# 6             항문암식  No information available  No information available
# 7  프로피온산혈증, 프로피온산증  No information available  No information available
# 8      프라더 윌리 증후군식  No information available  No information available
# 9              폐렴식  No information available  No information available
#
#                        권장식품                      주의식품  \
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available
#
#                    그 외 주의사항                     추천 식단
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            content = diet_therapy_tag.get_text(separator="\n")
            content_lines = content.split("\n")

            # 각 섹션을 분리하여 저장
            dietary_therapy = {
                "식사요법의 필요성": "",
                "식사요법의 실제": "",
                "권장식품": "",
                "주의식품": "",
                "그 외 주의사항": "",
                "추천 식단": ""
            }
            current_section = None
            for line in content_lines:
                if line.strip() in dietary_therapy:
                    current_section = line.strip()
                elif current_section:
                    dietary_therapy[current_section] += line.strip() + "\n"

        else:
            dietary_therapy = {"식사요법의 필요성": "No information available",
                               "식사요법의 실제": "No information available",
                               "권장식품": "No information available",
                               "주의식품": "No information available",
                               "그 외 주의사항": "No information available",
                               "추천 식단": "No information available"}

        # 결과를 리스트에 추가
        data.append({"Disease Name": disease_name, **dietary_therapy})

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    fieldnames = ["Disease Name", "식사요법의 필요성", "식사요법의 실제", "권장식품", "주의식품", "그 외 주의사항", "추천 식단"]
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name                 식사요법의 필요성                  식사요법의 실제  \
# 0        후천성면역결핍증식  No information available  No information available
# 1             후두암식  No information available  No information available
# 2              화상식  No information available  No information available
# 3         호모시스틴뇨증식  No information available  No information available
# 4             협심증식  No information available  No information available
# 5         허혈성심장질환식  No information available  No information available
# 6             항문암식  No information available  No information available
# 7  프로피온산혈증, 프로피온산증  No information available  No information available
# 8      프라더 윌리 증후군식  No information available  No information available
# 9              폐렴식  No information available  No information available
#
#                        권장식품                      주의식품  \
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available
#
#                    그 외 주의사항                     추천 식단
# 0  No information available  No information available
# 1  No information available  No information available
# 2  No information available  No information available
# 3  No information available  No information available
# 4  No information available  No information available
# 5  No information available  No information available
# 6  No information available  No information available
# 7  No information available  No information available
# 8  No information available  No information available
# 9  No information available  No information available

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
contents = []

# 본문 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("div", class_="info_contents")
        if diet_therapy_tag:
            content = diet_therapy_tag.get_text(separator="\n")
            contents.append(content.strip())
        else:
            contents.append("No information available")

# 결과 출력
for idx, content in enumerate(contents, 1):
    print(f"본문 {idx}: {content}\n")
# Out:
# 본문 1: No information available
#
# 본문 2: No information available
#
# 본문 3: No information available
#
# 본문 4: No information available
#
# 본문 5: No information available
#
# 본문 6: No information available
#
# 본문 7: No information available
#
# 본문 8: No information available
#
# 본문 9: No information available
#
# 본문 10: No information available

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("dl", class_="descDl")
        if diet_therapy_tag:
            diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
            diet_therapy_dict = {}
            current_key = None
            for item in diet_therapy_content:
                if item.name == "dt":
                    current_key = item.text.strip()
                elif item.name == "dd" and current_key:
                    diet_therapy_dict[current_key] = item.text.strip()
            # 결과를 리스트에 추가
            data.append([disease_name, diet_therapy_dict])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["질병이름", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항", "추천 식단"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        diet_therapy_dict = row[1]
        row_data = [disease_name]
        for header in headers[1:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#       Disease Name                                          식사요법의 필요성  \
# 0        후천성면역결핍증식  필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1             후두암식  후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2              화상식  화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3         호모시스틴뇨증식  호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4             협심증식  협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# 5         허혈성심장질환식  심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다. \n[콜레스테롤에...
# 6             항문암식  수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며, 수술 후 약 6주 ...
# 7  프로피온산혈증, 프로피온산증  발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에 관여하는 propi...
# 8      프라더 윌리 증후군식                        비만으로 인한 합병증을 조절하기 위해 필요합니다.
# 9              폐렴식  증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방지하기 위하여 충분한...
#
#                                             식사요법의 실제  \
# 0  1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1  암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2  1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3  1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 5  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 6  1. 고섬유질 식품 섭취를 줄입니다. (잡곡류, 채소 및 해조류, 과일류, 견과류 ...
# 7  1. 루이신, 이소루이신, 발린, 메티오닌, 트레오닌 등 프로피온산의 전구물질이 될...
# 8  1. 보통의 비만아보다 더 강하게 열량을 제한합니다.\r\n2. 당뇨가 동반된 경우...
# 9  1. 과식보다는 간식과 함께 소량씩 자주 섭취합니다.\r\n2. 매끼 양질의 어육류...
#
#                                                권장 식품  \
# 0  양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1  현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2  곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                               곡류, 채소류, 과일류, 식물성 기름
# 4  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 5  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 6  수술직후 : 쌀밥, 흰국수, 생선, 계란, 두부, 육류(결체조직 및 껍질 제외), 유제품
# 7      쌀, 고구마, 감자 등 탄수화물 식품과 식물성 기름, 버터류, 모든 채소와 과일류
# 8  잡곡밥, 신선한 채소와 과일(당뇨가 있는 경우는 별도의 양 조절 필요), 해조류, ...
# 9                부드러운 살코기, 생선, 요구르트, 다양한 색상의 과일이나 채소
#
#                                                주의 식품  \
# 0  과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                            술, 비위생적인 식품, 가공식품, 탄 음식
# 2  단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                  콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 5  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 6       수술직후 : 잡곡, 질긴 채소, 건조 과일과 껍질, 씨앗, 견과류, 자극성 식품
# 7  쇠고기, 돼지고기, 닭고기, 생선 및 가공품, 우유 및 유제품 등 발린 함량이 높은...
# 8  사탕이나 초컬렛, 청량음료, 단 빵류 (케익 포함) 와 같이 단순당 또는 단순당이 ...
# 9                                         튀김, 육류의 기름
#
#                                             그 외 주의사항  추천 식단
# 0          흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.    NaN
# 1  환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...    NaN
# 2  1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...    NaN
# 3  처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...    NaN
# 4  소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...    NaN
# 5  오메가-3 지방산은 에이코사펜타엔산(EPA), 도코사헥사엔산(DHA) 등으로 주로 ...    NaN
# 6  1. 수술 직후 약 6주간 고섬유식품 섭취를 줄이도록 합니다. \r\n2. 수술 부...    NaN
# 7  여러가지 감염, 예방접종, 외상, 마취 및 수술과 같은 상황이 발생하면 단백질 섭취...    NaN
# 8  기름지지 않은 음식이라 하더라도 식욕만큼 배를 채우게 되면 체중이 쉽게 늘어나므로 ...    NaN
# 9  잦은 가래 배출로 몸에 수분이 부족하기 쉬우므로 수시로 과일쥬스나 물 등으로 보충하...    NaN

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 관련 질환과 동의어 가져오기
        related_conditions_tag = disease_soup.find("dl", class_="linkDl")
        related_conditions = related_conditions_tag.text.strip() if related_conditions_tag else ""

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("dl", class_="descDl")
        if diet_therapy_tag:
            diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
            diet_therapy_dict = {}
            current_key = None
            for item in diet_therapy_content:
                if item.name == "dt":
                    current_key = item.text.strip()
                elif item.name == "dd" and current_key:
                    diet_therapy_dict[current_key] = item.text.strip()
            # 결과를 리스트에 추가
            data.append([disease_name, related_conditions, diet_therapy_dict])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["질병이름", "Related Conditions", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항", "추천 식단"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions = row[1]
        diet_therapy_dict = row[2]
        row_data = [disease_name, related_conditions]
        for header in headers[2:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#               질병이름  Related Conditions  \
# 0        후천성면역결핍증식                 NaN
# 1             후두암식                 NaN
# 2              화상식                 NaN
# 3         호모시스틴뇨증식                 NaN
# 4             협심증식                 NaN
# 5         허혈성심장질환식                 NaN
# 6             항문암식                 NaN
# 7  프로피온산혈증, 프로피온산증                 NaN
# 8      프라더 윌리 증후군식                 NaN
# 9              폐렴식                 NaN
#
#                                            식사요법의 필요성  \
# 0  필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1  후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2  화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3  호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4  협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# 5  심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다. \n[콜레스테롤에...
# 6  수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며, 수술 후 약 6주 ...
# 7  발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에 관여하는 propi...
# 8                        비만으로 인한 합병증을 조절하기 위해 필요합니다.
# 9  증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방지하기 위하여 충분한...
#
#                                             식사요법의 실제  \
# 0  1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1  암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2  1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3  1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 5  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 6  1. 고섬유질 식품 섭취를 줄입니다. (잡곡류, 채소 및 해조류, 과일류, 견과류 ...
# 7  1. 루이신, 이소루이신, 발린, 메티오닌, 트레오닌 등 프로피온산의 전구물질이 될...
# 8  1. 보통의 비만아보다 더 강하게 열량을 제한합니다.\r\n2. 당뇨가 동반된 경우...
# 9  1. 과식보다는 간식과 함께 소량씩 자주 섭취합니다.\r\n2. 매끼 양질의 어육류...
#
#                                                권장 식품  \
# 0  양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1  현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2  곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                               곡류, 채소류, 과일류, 식물성 기름
# 4  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 5  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 6  수술직후 : 쌀밥, 흰국수, 생선, 계란, 두부, 육류(결체조직 및 껍질 제외), 유제품
# 7      쌀, 고구마, 감자 등 탄수화물 식품과 식물성 기름, 버터류, 모든 채소와 과일류
# 8  잡곡밥, 신선한 채소와 과일(당뇨가 있는 경우는 별도의 양 조절 필요), 해조류, ...
# 9                부드러운 살코기, 생선, 요구르트, 다양한 색상의 과일이나 채소
#
#                                                주의 식품  \
# 0  과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                            술, 비위생적인 식품, 가공식품, 탄 음식
# 2  단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                  콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 5  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 6       수술직후 : 잡곡, 질긴 채소, 건조 과일과 껍질, 씨앗, 견과류, 자극성 식품
# 7  쇠고기, 돼지고기, 닭고기, 생선 및 가공품, 우유 및 유제품 등 발린 함량이 높은...
# 8  사탕이나 초컬렛, 청량음료, 단 빵류 (케익 포함) 와 같이 단순당 또는 단순당이 ...
# 9                                         튀김, 육류의 기름
#
#                                             그 외 주의사항  추천 식단
# 0          흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.    NaN
# 1  환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...    NaN
# 2  1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...    NaN
# 3  처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...    NaN
# 4  소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...    NaN
# 5  오메가-3 지방산은 에이코사펜타엔산(EPA), 도코사헥사엔산(DHA) 등으로 주로 ...    NaN
# 6  1. 수술 직후 약 6주간 고섬유식품 섭취를 줄이도록 합니다. \r\n2. 수술 부...    NaN
# 7  여러가지 감염, 예방접종, 외상, 마취 및 수술과 같은 상황이 발생하면 단백질 섭취...    NaN
# 8  기름지지 않은 음식이라 하더라도 식욕만큼 배를 채우게 되면 체중이 쉽게 늘어나므로 ...    NaN
# 9  잦은 가래 배출로 몸에 수분이 부족하기 쉬우므로 수시로 과일쥬스나 물 등으로 보충하...    NaN

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 관련 질환과 동의어 가져오기
        related_conditions_tag = disease_soup.find("div", class_="contBox")
        related_conditions_text = related_conditions_tag.text.strip() if related_conditions_tag else ""

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("dl", class_="descDl")
        if diet_therapy_tag:
            diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
            diet_therapy_dict = {}
            current_key = None
            for item in diet_therapy_content:
                if item.name == "dt":
                    current_key = item.text.strip()
                elif item.name == "dd" and current_key:
                    diet_therapy_dict[current_key] = item.text.strip()
            # 결과를 리스트에 추가
            data.append([disease_name, related_conditions_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["질병이름", "관련 질환 및 동의어", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항", "추천 식단"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions_text = row[1]
        diet_therapy_dict = row[2]
        row_data = [disease_name, related_conditions_text]
        for header in headers[2:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#               질병이름                                        관련 질환 및 동의어  \
# 0        후천성면역결핍증식         후천성면역결핍증식\n\n관련질환\n\n후천성 면역결핍증\n\n동의어\n에이즈
# 1             후두암식       후두암식\n\n관련질환\n\n후두암\n\n동의어\n후두암의 식사, 암환자의 영양
# 2              화상식                       화상식\n\n관련질환\n\n화상\n\n동의어\n화상
# 3         호모시스틴뇨증식  호모시스틴뇨증식\n\n관련질환\n\n호모시스틴뇨증\n\n동의어\n호모시스틴뇨증, 고...
# 4             협심증식                                협심증식\n\n관련질환\n\n협심증
# 5         허혈성심장질환식          허혈성심장질환식\n\n관련질환\n\n허혈성 심질환\n\n동의어\n심장병식사
# 6             항문암식                                항문암식\n\n관련질환\n\n항문암
# 7  프로피온산혈증, 프로피온산증  프로피온산혈증, 프로피온산증\n\n관련질환\n\n프로피온산증\n\n동의어\n프로피온...
# 8      프라더 윌리 증후군식  프라더 윌리 증후군식\n\n관련질환\n\n프라더 윌리 증후군 \n\n동의어\n프래더...
# 9              폐렴식                폐렴식\n\n관련질환\n\n폐렴\n\n동의어\n감기, 인플루엔자
#
#                                            식사요법의 필요성  \
# 0  필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1  후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2  화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3  호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4  협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# 5  심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다. \n[콜레스테롤에...
# 6  수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며, 수술 후 약 6주 ...
# 7  발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에 관여하는 propi...
# 8                        비만으로 인한 합병증을 조절하기 위해 필요합니다.
# 9  증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방지하기 위하여 충분한...
#
#                                             식사요법의 실제  \
# 0  1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1  암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2  1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3  1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 5  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 6  1. 고섬유질 식품 섭취를 줄입니다. (잡곡류, 채소 및 해조류, 과일류, 견과류 ...
# 7  1. 루이신, 이소루이신, 발린, 메티오닌, 트레오닌 등 프로피온산의 전구물질이 될...
# 8  1. 보통의 비만아보다 더 강하게 열량을 제한합니다.\r\n2. 당뇨가 동반된 경우...
# 9  1. 과식보다는 간식과 함께 소량씩 자주 섭취합니다.\r\n2. 매끼 양질의 어육류...
#
#                                                권장 식품  \
# 0  양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1  현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2  곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                               곡류, 채소류, 과일류, 식물성 기름
# 4  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 5  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 6  수술직후 : 쌀밥, 흰국수, 생선, 계란, 두부, 육류(결체조직 및 껍질 제외), 유제품
# 7      쌀, 고구마, 감자 등 탄수화물 식품과 식물성 기름, 버터류, 모든 채소와 과일류
# 8  잡곡밥, 신선한 채소와 과일(당뇨가 있는 경우는 별도의 양 조절 필요), 해조류, ...
# 9                부드러운 살코기, 생선, 요구르트, 다양한 색상의 과일이나 채소
#
#                                                주의 식품  \
# 0  과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                            술, 비위생적인 식품, 가공식품, 탄 음식
# 2  단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                  콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 5  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 6       수술직후 : 잡곡, 질긴 채소, 건조 과일과 껍질, 씨앗, 견과류, 자극성 식품
# 7  쇠고기, 돼지고기, 닭고기, 생선 및 가공품, 우유 및 유제품 등 발린 함량이 높은...
# 8  사탕이나 초컬렛, 청량음료, 단 빵류 (케익 포함) 와 같이 단순당 또는 단순당이 ...
# 9                                         튀김, 육류의 기름
#
#                                             그 외 주의사항  추천 식단
# 0          흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.    NaN
# 1  환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...    NaN
# 2  1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...    NaN
# 3  처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...    NaN
# 4  소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...    NaN
# 5  오메가-3 지방산은 에이코사펜타엔산(EPA), 도코사헥사엔산(DHA) 등으로 주로 ...    NaN
# 6  1. 수술 직후 약 6주간 고섬유식품 섭취를 줄이도록 합니다. \r\n2. 수술 부...    NaN
# 7  여러가지 감염, 예방접종, 외상, 마취 및 수술과 같은 상황이 발생하면 단백질 섭취...    NaN
# 8  기름지지 않은 음식이라 하더라도 식욕만큼 배를 채우게 되면 체중이 쉽게 늘어나므로 ...    NaN
# 9  잦은 가래 배출로 몸에 수분이 부족하기 쉬우므로 수시로 과일쥬스나 물 등으로 보충하...    NaN

# %%
import requests
from bs4 import BeautifulSoup
import csv

url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 상세 페이지의 HTML 가져오기
        disease_response = requests.get(disease_link).text
        disease_soup = BeautifulSoup(disease_response, "html.parser")

        # 관련 질환과 동의어 가져오기
        related_conditions_tag = disease_soup.find("div", class_="contBox")
        related_conditions_text = ""
        synonyms_text = ""
        if related_conditions_tag:
            related_conditions_tag = related_conditions_tag.find_all("dd")
            if len(related_conditions_tag) >= 2:
                related_conditions_text = related_conditions_tag[0].text.strip()
                synonyms_text = related_conditions_tag[1].text.strip()
            elif len(related_conditions_tag) == 1:
                related_conditions_text = related_conditions_tag[0].text.strip()

        # 본문 내용 가져오기
        diet_therapy_tag = disease_soup.find("dl", class_="descDl")
        if diet_therapy_tag:
            diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
            diet_therapy_dict = {}
            current_key = None
            for item in diet_therapy_content:
                if item.name == "dt":
                    current_key = item.text.strip()
                elif item.name == "dd" and current_key:
                    diet_therapy_dict[current_key] = item.text.strip()
            # 결과를 리스트에 추가
            data.append([disease_name, related_conditions_text, synonyms_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["질병이름", "관련 질환", "동의어", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항", "추천 식단"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions_text = row[1]
        synonyms_text = row[2]
        diet_therapy_dict = row[3]
        row_data = [disease_name, related_conditions_text, synonyms_text]
        for header in headers[3:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#               질병이름       관련 질환                     동의어  \
# 0        후천성면역결핍증식   후천성 면역결핍증                     에이즈
# 1             후두암식         후두암        후두암의 식사, 암환자의 영양
# 2              화상식          화상                      화상
# 3         호모시스틴뇨증식     호모시스틴뇨증        호모시스틴뇨증, 고메티오닌혈증
# 4             협심증식         협심증                     NaN
# 5         허혈성심장질환식     허혈성 심질환                   심장병식사
# 6             항문암식         항문암                     NaN
# 7  프로피온산혈증, 프로피온산증      프로피온산증  프로피온산혈증, 프로피온산증, 유기산혈증
# 8      프라더 윌리 증후군식  프라더 윌리 증후군          프래더 윌리 증후군, 비만
# 9              폐렴식          폐렴               감기, 인플루엔자
#
#                                            식사요법의 필요성  \
# 0  필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1  후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2  화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3  호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4  협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# 5  심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다. \n[콜레스테롤에...
# 6  수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며, 수술 후 약 6주 ...
# 7  발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에 관여하는 propi...
# 8                        비만으로 인한 합병증을 조절하기 위해 필요합니다.
# 9  증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방지하기 위하여 충분한...
#
#                                             식사요법의 실제  \
# 0  1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1  암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2  1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3  1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 5  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 6  1. 고섬유질 식품 섭취를 줄입니다. (잡곡류, 채소 및 해조류, 과일류, 견과류 ...
# 7  1. 루이신, 이소루이신, 발린, 메티오닌, 트레오닌 등 프로피온산의 전구물질이 될...
# 8  1. 보통의 비만아보다 더 강하게 열량을 제한합니다.\r\n2. 당뇨가 동반된 경우...
# 9  1. 과식보다는 간식과 함께 소량씩 자주 섭취합니다.\r\n2. 매끼 양질의 어육류...
#
#                                                권장 식품  \
# 0  양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1  현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2  곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                               곡류, 채소류, 과일류, 식물성 기름
# 4  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 5  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 6  수술직후 : 쌀밥, 흰국수, 생선, 계란, 두부, 육류(결체조직 및 껍질 제외), 유제품
# 7      쌀, 고구마, 감자 등 탄수화물 식품과 식물성 기름, 버터류, 모든 채소와 과일류
# 8  잡곡밥, 신선한 채소와 과일(당뇨가 있는 경우는 별도의 양 조절 필요), 해조류, ...
# 9                부드러운 살코기, 생선, 요구르트, 다양한 색상의 과일이나 채소
#
#                                                주의 식품  \
# 0  과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                            술, 비위생적인 식품, 가공식품, 탄 음식
# 2  단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                  콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 5  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 6       수술직후 : 잡곡, 질긴 채소, 건조 과일과 껍질, 씨앗, 견과류, 자극성 식품
# 7  쇠고기, 돼지고기, 닭고기, 생선 및 가공품, 우유 및 유제품 등 발린 함량이 높은...
# 8  사탕이나 초컬렛, 청량음료, 단 빵류 (케익 포함) 와 같이 단순당 또는 단순당이 ...
# 9                                         튀김, 육류의 기름
#
#                                             그 외 주의사항  추천 식단
# 0          흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.    NaN
# 1  환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...    NaN
# 2  1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...    NaN
# 3  처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...    NaN
# 4  소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...    NaN
# 5  오메가-3 지방산은 에이코사펜타엔산(EPA), 도코사헥사엔산(DHA) 등으로 주로 ...    NaN
# 6  1. 수술 직후 약 6주간 고섬유식품 섭취를 줄이도록 합니다. \r\n2. 수술 부...    NaN
# 7  여러가지 감염, 예방접종, 외상, 마취 및 수술과 같은 상황이 발생하면 단백질 섭취...    NaN
# 8  기름지지 않은 음식이라 하더라도 식욕만큼 배를 채우게 되면 체중이 쉽게 늘어나므로 ...    NaN
# 9  잦은 가래 배출로 몸에 수분이 부족하기 쉬우므로 수시로 과일쥬스나 물 등으로 보충하...    NaN

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 기본 URL과 페이지 수 설정
base_url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?page="
total_pages = 10  # 예시로 10 페이지까지만 순회하도록 설정

# 결과를 담을 빈 리스트 생성
data = []

# 각 페이지를 순회하며 데이터 추출
for page_number in range(1, total_pages + 1):
    url = base_url + str(page_number)
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
                diet_therapy_dict = {}
                current_key = None
                for item in diet_therapy_content:
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()
                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["질병이름", "관련 질환", "동의어", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항", "추천 식단"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions_text = row[1]
        synonyms_text = row[2]
        diet_therapy_dict = row[3]
        row_data = [disease_name, related_conditions_text, synonyms_text]
        for header in headers[3:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df[5:11]
# Out:
#                질병이름       관련 질환                     동의어  \
# 5          허혈성심장질환식     허혈성 심질환                   심장병식사
# 6              항문암식         항문암                     NaN
# 7   프로피온산혈증, 프로피온산증      프로피온산증  프로피온산혈증, 프로피온산증, 유기산혈증
# 8       프라더 윌리 증후군식  프라더 윌리 증후군          프래더 윌리 증후군, 비만
# 9               폐렴식          폐렴               감기, 인플루엔자
# 10        후천성면역결핍증식   후천성 면역결핍증                     에이즈
#
#                                             식사요법의 필요성  \
# 5   심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다. \n[콜레스테롤에...
# 6   수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며, 수술 후 약 6주 ...
# 7   발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에 관여하는 propi...
# 8                         비만으로 인한 합병증을 조절하기 위해 필요합니다.
# 9   증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방지하기 위하여 충분한...
# 10  필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
#
#                                              식사요법의 실제  \
# 5   1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 6   1. 고섬유질 식품 섭취를 줄입니다. (잡곡류, 채소 및 해조류, 과일류, 견과류 ...
# 7   1. 루이신, 이소루이신, 발린, 메티오닌, 트레오닌 등 프로피온산의 전구물질이 될...
# 8   1. 보통의 비만아보다 더 강하게 열량을 제한합니다.\r\n2. 당뇨가 동반된 경우...
# 9   1. 과식보다는 간식과 함께 소량씩 자주 섭취합니다.\r\n2. 매끼 양질의 어육류...
# 10  1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
#
#                                                 권장 식품  \
# 5   신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 6   수술직후 : 쌀밥, 흰국수, 생선, 계란, 두부, 육류(결체조직 및 껍질 제외), 유제품
# 7       쌀, 고구마, 감자 등 탄수화물 식품과 식물성 기름, 버터류, 모든 채소와 과일류
# 8   잡곡밥, 신선한 채소와 과일(당뇨가 있는 경우는 별도의 양 조절 필요), 해조류, ...
# 9                 부드러운 살코기, 생선, 요구르트, 다양한 색상의 과일이나 채소
# 10  양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
#
#                                                 주의 식품  \
# 5   고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 6        수술직후 : 잡곡, 질긴 채소, 건조 과일과 껍질, 씨앗, 견과류, 자극성 식품
# 7   쇠고기, 돼지고기, 닭고기, 생선 및 가공품, 우유 및 유제품 등 발린 함량이 높은...
# 8   사탕이나 초컬렛, 청량음료, 단 빵류 (케익 포함) 와 같이 단순당 또는 단순당이 ...
# 9                                          튀김, 육류의 기름
# 10  과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
#
#                                              그 외 주의사항  추천 식단
# 5   오메가-3 지방산은 에이코사펜타엔산(EPA), 도코사헥사엔산(DHA) 등으로 주로 ...    NaN
# 6   1. 수술 직후 약 6주간 고섬유식품 섭취를 줄이도록 합니다. \r\n2. 수술 부...    NaN
# 7   여러가지 감염, 예방접종, 외상, 마취 및 수술과 같은 상황이 발생하면 단백질 섭취...    NaN
# 8   기름지지 않은 음식이라 하더라도 식욕만큼 배를 채우게 되면 체중이 쉽게 늘어나므로 ...    NaN
# 9   잦은 가래 배출로 몸에 수분이 부족하기 쉬우므로 수시로 과일쥬스나 물 등으로 보충하...    NaN
# 10          흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.    NaN

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 기본 URL 설정
base_url = "https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do"
response = requests.get(base_url).text
soup = BeautifulSoup(response, "html.parser")

# 결과를 담을 빈 리스트 생성
data = []

# 질병명과 링크 가져오기
for disease in soup.find_all("dt"):
    disease_name_tag = disease.find("a", class_="txtellipsis")
    if disease_name_tag:
        disease_name = disease_name_tag.text.strip()
        disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

        # 중복 체크
        if disease_name not in [row[0] for row in data]:
            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
                diet_therapy_dict = {}
                current_key = None
                for item in diet_therapy_content:
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()
                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["질병이름", "관련 질환", "동의어", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항", "추천 식단"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions_text = row[1]
        synonyms_text = row[2]
        diet_therapy_dict = row[3]
        row_data = [disease_name, related_conditions_text, synonyms_text]
        for header in headers[3:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#               질병이름       관련 질환                     동의어  \
# 0        후천성면역결핍증식   후천성 면역결핍증                     에이즈
# 1             후두암식         후두암        후두암의 식사, 암환자의 영양
# 2              화상식          화상                      화상
# 3         호모시스틴뇨증식     호모시스틴뇨증        호모시스틴뇨증, 고메티오닌혈증
# 4             협심증식         협심증                     NaN
# 5         허혈성심장질환식     허혈성 심질환                   심장병식사
# 6             항문암식         항문암                     NaN
# 7  프로피온산혈증, 프로피온산증      프로피온산증  프로피온산혈증, 프로피온산증, 유기산혈증
# 8      프라더 윌리 증후군식  프라더 윌리 증후군          프래더 윌리 증후군, 비만
# 9              폐렴식          폐렴               감기, 인플루엔자
#
#                                            식사요법의 필요성  \
# 0  필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1  후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2  화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3  호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4  협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# 5  심장질환 시 식사요법은 크게 3가지로 나누어 생각할 수 있습니다. \n[콜레스테롤에...
# 6  수술 직후 회복을 위한 충분한 열량과 단백질을 섭취하도록 하며, 수술 후 약 6주 ...
# 7  발린, 이소로이신, 메치오닌, 스레오닌과 같은 아미노산의 대사에 관여하는 propi...
# 8                        비만으로 인한 합병증을 조절하기 위해 필요합니다.
# 9  증상의 진행 중 식사량 감소로 인한 체중감소와 체조직 소모를 방지하기 위하여 충분한...
#
#                                             식사요법의 실제  \
# 0  1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1  암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2  1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3  1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 5  1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# 6  1. 고섬유질 식품 섭취를 줄입니다. (잡곡류, 채소 및 해조류, 과일류, 견과류 ...
# 7  1. 루이신, 이소루이신, 발린, 메티오닌, 트레오닌 등 프로피온산의 전구물질이 될...
# 8  1. 보통의 비만아보다 더 강하게 열량을 제한합니다.\r\n2. 당뇨가 동반된 경우...
# 9  1. 과식보다는 간식과 함께 소량씩 자주 섭취합니다.\r\n2. 매끼 양질의 어육류...
#
#                                                권장 식품  \
# 0  양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1  현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2  곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                               곡류, 채소류, 과일류, 식물성 기름
# 4  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 5  신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# 6  수술직후 : 쌀밥, 흰국수, 생선, 계란, 두부, 육류(결체조직 및 껍질 제외), 유제품
# 7      쌀, 고구마, 감자 등 탄수화물 식품과 식물성 기름, 버터류, 모든 채소와 과일류
# 8  잡곡밥, 신선한 채소와 과일(당뇨가 있는 경우는 별도의 양 조절 필요), 해조류, ...
# 9                부드러운 살코기, 생선, 요구르트, 다양한 색상의 과일이나 채소
#
#                                                주의 식품  \
# 0  과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                            술, 비위생적인 식품, 가공식품, 탄 음식
# 2  단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                  콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 5  고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# 6       수술직후 : 잡곡, 질긴 채소, 건조 과일과 껍질, 씨앗, 견과류, 자극성 식품
# 7  쇠고기, 돼지고기, 닭고기, 생선 및 가공품, 우유 및 유제품 등 발린 함량이 높은...
# 8  사탕이나 초컬렛, 청량음료, 단 빵류 (케익 포함) 와 같이 단순당 또는 단순당이 ...
# 9                                         튀김, 육류의 기름
#
#                                             그 외 주의사항  추천 식단
# 0          흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.    NaN
# 1  환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...    NaN
# 2  1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...    NaN
# 3  처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...    NaN
# 4  소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...    NaN
# 5  오메가-3 지방산은 에이코사펜타엔산(EPA), 도코사헥사엔산(DHA) 등으로 주로 ...    NaN
# 6  1. 수술 직후 약 6주간 고섬유식품 섭취를 줄이도록 합니다. \r\n2. 수술 부...    NaN
# 7  여러가지 감염, 예방접종, 외상, 마취 및 수술과 같은 상황이 발생하면 단백질 섭취...    NaN
# 8  기름지지 않은 음식이라 하더라도 식욕만큼 배를 채우게 되면 체중이 쉽게 늘어나므로 ...    NaN
# 9  잦은 가래 배출로 몸에 수분이 부족하기 쉬우므로 수시로 과일쥬스나 물 등으로 보충하...    NaN

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
                diet_therapy_dict = {}
                current_key = None
                for item in diet_therapy_content:
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()
                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", newline="", encoding="utf-8") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["질병이름", "관련 질환", "동의어", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions_text = row[1]
        synonyms_text = row[2]
        diet_therapy_dict = row[3]
        row_data = [disease_name, related_conditions_text, synonyms_text]
        for header in headers[3:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#           질병이름      관련 질환                  동의어  \
# 0    후천성면역결핍증식  후천성 면역결핍증                  에이즈
# 1         후두암식        후두암     후두암의 식사, 암환자의 영양
# 2          화상식         화상                   화상
# 3     호모시스틴뇨증식    호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4         협심증식        협심증                  NaN
# ..         ...        ...                  ...
# 99    갑상선기능저하증   갑상선기능저하증             균형식, 일반식
# 100      간이식후식   간이식 후 상태           고열량식, 고단백식
# 101      간성혼수식      간성 뇌증                 간성뇌증
# 102       간경화식        간경화             간질환, 간경변
# 103       각기병식        각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                                              식사요법의 필요성  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                               식사요법의 실제  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                                  권장 식품  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                                  주의 식품  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                               그 외 주의사항
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...
# ..                                                 ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.
#
# [104 rows x 8 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv
import codecs  # codecs 모듈을 추가합니다.

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
                diet_therapy_dict = {}
                current_key = None
                for item in diet_therapy_content:
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()
                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with codecs.open("disease_data.csv", "w", encoding="utf-8-sig") as csvfile:  # codecs 모듈을 사용하여 파일을 열고 "utf-8-sig"로 설정합니다.
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["질병이름", "관련 질환", "동의어", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions_text = row[1]
        synonyms_text = row[2]
        diet_therapy_dict = row[3]
        row_data = [disease_name, related_conditions_text, synonyms_text]
        for header in headers[3:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import requests
from bs4 import BeautifulSoup
import csv
import codecs

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                diet_therapy_content = diet_therapy_tag.find_all(["dt", "dd"])
                diet_therapy_dict = {}
                current_key = None
                for item in diet_therapy_content:
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()
                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with codecs.open("disease_data.csv", "w", encoding="utf-8-sig") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["disease_specific_diet","disease_name", "synonyms", "식사요법의 필요성", "식사요법의 실제", "권장 식품", "주의 식품", "그 외 주의사항"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions_text = row[1]
        synonyms_text = row[2]
        diet_therapy_dict = row[3]
        row_data = [disease_name, related_conditions_text, synonyms_text]
        for header in headers[3:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_specific_diet disease_name             synonyms  \
# 0               후천성면역결핍증식    후천성 면역결핍증                  에이즈
# 1                    후두암식          후두암     후두암의 식사, 암환자의 영양
# 2                     화상식           화상                   화상
# 3                호모시스틴뇨증식      호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4                    협심증식          협심증                  NaN
# ..                    ...          ...                  ...
# 99               갑상선기능저하증     갑상선기능저하증             균형식, 일반식
# 100                 간이식후식     간이식 후 상태           고열량식, 고단백식
# 101                 간성혼수식        간성 뇌증                 간성뇌증
# 102                  간경화식          간경화             간질환, 간경변
# 103                  각기병식          각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                                              식사요법의 필요성  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                               식사요법의 실제  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                                  권장 식품  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                                  주의 식품  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                               그 외 주의사항
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...
# ..                                                 ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.
#
# [104 rows x 8 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv
import codecs

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with codecs.open("disease_data.csv", "w", encoding="utf-8-sig") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성
    headers = ["disease_specific_diet","disease_name", "synonyms", "importance_of_diet_therapy", "actual_diet_therapy", "recommended_food", "caution_food", "other_notes"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        disease_name = row[0]
        related_conditions_text = row[1]
        synonyms_text = row[2]
        diet_therapy_dict = row[3]
        row_data = [disease_name, related_conditions_text, synonyms_text]

        # 칼럼 정보를 찾아서 해당하는 텍스트를 가져옵니다.
        for header in headers[3:]:
            row_data.append(diet_therapy_dict.get(header, ""))
        writer.writerow(row_data)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_specific_diet disease_name             synonyms  \
# 0               후천성면역결핍증식    후천성 면역결핍증                  에이즈
# 1                    후두암식          후두암     후두암의 식사, 암환자의 영양
# 2                     화상식           화상                   화상
# 3                호모시스틴뇨증식      호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4                    협심증식          협심증                  NaN
# ..                    ...          ...                  ...
# 99               갑상선기능저하증     갑상선기능저하증             균형식, 일반식
# 100                 간이식후식     간이식 후 상태           고열량식, 고단백식
# 101                 간성혼수식        간성 뇌증                 간성뇌증
# 102                  간경화식          간경화             간질환, 간경변
# 103                  각기병식          각기병  티아민 결핍증, 비타민 B1 결핍증
#
#      importance_of_diet_therapy  actual_diet_therapy  recommended_food  \
# 0                           NaN                  NaN               NaN
# 1                           NaN                  NaN               NaN
# 2                           NaN                  NaN               NaN
# 3                           NaN                  NaN               NaN
# 4                           NaN                  NaN               NaN
# ..                          ...                  ...               ...
# 99                          NaN                  NaN               NaN
# 100                         NaN                  NaN               NaN
# 101                         NaN                  NaN               NaN
# 102                         NaN                  NaN               NaN
# 103                         NaN                  NaN               NaN
#
#      caution_food  other_notes
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ..            ...          ...
# 99            NaN          NaN
# 100           NaN          NaN
# 101           NaN          NaN
# 102           NaN          NaN
# 103           NaN          NaN
#
# [104 rows x 8 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text, diet_therapy_dict])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_name", "related_conditions", "synonyms", "importance_of_diet_therapy", "actual_diet_therapy", "recommended_food", "caution_food", "other_notes"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_name related_conditions             synonyms  \
# 0      후천성면역결핍증식          후천성 면역결핍증                  에이즈
# 1           후두암식                후두암     후두암의 식사, 암환자의 영양
# 2            화상식                 화상                   화상
# 3       호모시스틴뇨증식            호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4           협심증식                협심증                  NaN
# ..           ...                ...                  ...
# 99      갑상선기능저하증           갑상선기능저하증             균형식, 일반식
# 100        간이식후식           간이식 후 상태           고열량식, 고단백식
# 101        간성혼수식              간성 뇌증                 간성뇌증
# 102         간경화식                간경화             간질환, 간경변
# 103         각기병식                각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                             importance_of_diet_therapy  actual_diet_therapy  \
# 0    {'식사요법의 필요성': '필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 ...                  NaN
# 1    {'식사요법의 필요성': '후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해...                  NaN
# 2    {'식사요법의 필요성': '화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배...                  NaN
# 3    {'식사요법의 필요성': '호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생...                  NaN
# 4    {'식사요법의 필요성': '협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져...                  NaN
# ..                                                 ...                  ...
# 99   {'식사요법의 필요성': '갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승...                  NaN
# 100  {'식사요법의 필요성': '간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 ...                  NaN
# 101  {'식사요법의 필요성': '고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유...                  NaN
# 102  {'식사요법의 필요성': '간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양...                  NaN
# 103  {'식사요법의 필요성': '비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로...                  NaN
#
#      recommended_food  caution_food  other_notes
# 0                 NaN           NaN          NaN
# 1                 NaN           NaN          NaN
# 2                 NaN           NaN          NaN
# 3                 NaN           NaN          NaN
# 4                 NaN           NaN          NaN
# ..                ...           ...          ...
# 99                NaN           NaN          NaN
# 100               NaN           NaN          NaN
# 101               NaN           NaN          NaN
# 102               NaN           NaN          NaN
# 103               NaN           NaN          NaN
#
# [104 rows x 8 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 필요성", ""),
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", "")])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_specific_diet","disease_name", "synonyms", "importance_of_diet_therapy",
               "actual_diet_therapy", "recommended_food", "caution_food", "other_notes"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_specific_diet disease_name             synonyms  \
# 0               후천성면역결핍증식    후천성 면역결핍증                  에이즈
# 1                    후두암식          후두암     후두암의 식사, 암환자의 영양
# 2                     화상식           화상                   화상
# 3                호모시스틴뇨증식      호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4                    협심증식          협심증                  NaN
# ..                    ...          ...                  ...
# 99               갑상선기능저하증     갑상선기능저하증             균형식, 일반식
# 100                 간이식후식     간이식 후 상태           고열량식, 고단백식
# 101                 간성혼수식        간성 뇌증                 간성뇌증
# 102                  간경화식          간경화             간질환, 간경변
# 103                  각기병식          각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                             importance_of_diet_therapy  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                    actual_diet_therapy  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                       recommended_food  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                           caution_food  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                            other_notes
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...
# ..                                                 ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.
#
# [104 rows x 8 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # contentId 추출
            content_id = disease_link.split("=")[-1]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 필요성", ""),
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", ""),
                             content_id])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_name", "related_conditions", "synonyms", "importance_of_diet_therapy",
               "actual_diet_therapy", "recommended_food", "caution_food", "other_notes", "content_id"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_name related_conditions             synonyms  \
# 0      후천성면역결핍증식          후천성 면역결핍증                  에이즈
# 1           후두암식                후두암     후두암의 식사, 암환자의 영양
# 2            화상식                 화상                   화상
# 3       호모시스틴뇨증식            호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4           협심증식                협심증                  NaN
# ..           ...                ...                  ...
# 99      갑상선기능저하증           갑상선기능저하증             균형식, 일반식
# 100        간이식후식           간이식 후 상태           고열량식, 고단백식
# 101        간성혼수식              간성 뇌증                 간성뇌증
# 102         간경화식                간경화             간질환, 간경변
# 103         각기병식                각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                             importance_of_diet_therapy  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                    actual_diet_therapy  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                       recommended_food  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                           caution_food  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                            other_notes  content_id
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.         121
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...         120
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...         119
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...         118
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...         117
# ..                                                 ...         ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...          22
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.          21
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.          20
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.          19
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.          18
#
# [104 rows x 9 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # contentId 추출
            content_id = disease_link.split("=")[-1]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 필요성", ""),
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", ""),
                             content_id])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_name", "related_conditions", "synonyms", "importance_of_diet_therapy",
               "actual_diet_therapy", "recommended_food", "caution_food", "other_notes", "content_id"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_name related_conditions             synonyms  \
# 0      후천성면역결핍증식          후천성 면역결핍증                  에이즈
# 1           후두암식                후두암     후두암의 식사, 암환자의 영양
# 2            화상식                 화상                   화상
# 3       호모시스틴뇨증식            호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4           협심증식                협심증                  NaN
# ..           ...                ...                  ...
# 99      갑상선기능저하증           갑상선기능저하증             균형식, 일반식
# 100        간이식후식           간이식 후 상태           고열량식, 고단백식
# 101        간성혼수식              간성 뇌증                 간성뇌증
# 102         간경화식                간경화             간질환, 간경변
# 103         각기병식                각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                             importance_of_diet_therapy  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                    actual_diet_therapy  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                       recommended_food  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                           caution_food  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                            other_notes  content_id
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.         121
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...         120
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...         119
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...         118
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...         117
# ..                                                 ...         ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...          22
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.          21
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.          20
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.          19
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.          18
#
# [104 rows x 9 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # contentId 추출
            content_id_tag = disease_soup.find("a", href=True)
            if content_id_tag:
                content_id = content_id_tag["href"].split("=")[-1]
            else:
                content_id = "Not found"

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 필요성", ""),
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", ""),
                             content_id])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_name", "related_conditions", "synonyms", "importance_of_diet_therapy",
               "actual_diet_therapy", "recommended_food", "caution_food", "other_notes", "content_id"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_name related_conditions             synonyms  \
# 0      후천성면역결핍증식          후천성 면역결핍증                  에이즈
# 1           후두암식                후두암     후두암의 식사, 암환자의 영양
# 2            화상식                 화상                   화상
# 3       호모시스틴뇨증식            호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4           협심증식                협심증                  NaN
# ..           ...                ...                  ...
# 99      갑상선기능저하증           갑상선기능저하증             균형식, 일반식
# 100        간이식후식           간이식 후 상태           고열량식, 고단백식
# 101        간성혼수식              간성 뇌증                 간성뇌증
# 102         간경화식                간경화             간질환, 간경변
# 103         각기병식                각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                             importance_of_diet_therapy  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                    actual_diet_therapy  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                       recommended_food  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                           caution_food  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                            other_notes  \
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...
# ..                                                 ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.
#
#                            content_id
# 0    https://blog.naver.com/amc_seoul
# 1    https://blog.naver.com/amc_seoul
# 2    https://blog.naver.com/amc_seoul
# 3    https://blog.naver.com/amc_seoul
# 4    https://blog.naver.com/amc_seoul
# ..                                ...
# 99   https://blog.naver.com/amc_seoul
# 100  https://blog.naver.com/amc_seoul
# 101  https://blog.naver.com/amc_seoul
# 102  https://blog.naver.com/amc_seoul
# 103  https://blog.naver.com/amc_seoul
#
# [104 rows x 9 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # contentId 추출
            content_id = disease_link.split("=")[-1]

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 필요성", ""),
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", ""),
                             content_id])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_name", "related_conditions", "synonyms", "importance_of_diet_therapy",
               "actual_diet_therapy", "recommended_food", "caution_food", "other_notes", "content_id"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_name related_conditions             synonyms  \
# 0      후천성면역결핍증식          후천성 면역결핍증                  에이즈
# 1           후두암식                후두암     후두암의 식사, 암환자의 영양
# 2            화상식                 화상                   화상
# 3       호모시스틴뇨증식            호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4           협심증식                협심증                  NaN
# ..           ...                ...                  ...
# 99      갑상선기능저하증           갑상선기능저하증             균형식, 일반식
# 100        간이식후식           간이식 후 상태           고열량식, 고단백식
# 101        간성혼수식              간성 뇌증                 간성뇌증
# 102         간경화식                간경화             간질환, 간경변
# 103         각기병식                각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                             importance_of_diet_therapy  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                    actual_diet_therapy  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                       recommended_food  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                           caution_food  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                            other_notes  content_id
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.         121
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...         120
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...         119
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...         118
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...         117
# ..                                                 ...         ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...          22
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.          21
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.          20
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.          19
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.          18
#
# [104 rows x 9 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # contentId 가져오기
            content_id_tag = disease_soup.find("a", href=lambda href: href and "contentId=" in href)
            if content_id_tag:
                content_id = content_id_tag["href"].split("=")[-1].split('.')[0]
            else:
                content_id = ""

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 필요성", ""),
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", ""),
                             content_id])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_specific_diet","disease_name", "synonyms", "importance_of_diet_therapy", "actual_diet_therapy", "recommended_food", "caution_food", "other_notes","disease_id"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_specific_diet disease_name             synonyms  \
# 0               후천성면역결핍증식    후천성 면역결핍증                  에이즈
# 1                    후두암식          후두암     후두암의 식사, 암환자의 영양
# 2                     화상식           화상                   화상
# 3                호모시스틴뇨증식      호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4                    협심증식          협심증                  NaN
# ..                    ...          ...                  ...
# 99               갑상선기능저하증     갑상선기능저하증             균형식, 일반식
# 100                 간이식후식     간이식 후 상태           고열량식, 고단백식
# 101                 간성혼수식        간성 뇌증                 간성뇌증
# 102                  간경화식          간경화             간질환, 간경변
# 103                  각기병식          각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                             importance_of_diet_therapy  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                    actual_diet_therapy  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                       recommended_food  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                           caution_food  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                            other_notes  disease_id
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.     31627.0
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...     31961.0
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...     32321.0
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...     32369.0
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...     32179.0
# ..                                                 ...         ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...     30863.0
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.     31390.0
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.     32092.0
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.     30480.0
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.     31897.0
#
# [104 rows x 9 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # contentId 가져오기
            content_id_tag = disease_soup.find("a", href=lambda href: href and "contentId=" in href)
            if content_id_tag:
                content_id = content_id_tag["href"].split("=")[-1].split('.')[0]
                content_id = int(float(content_id))  # 문자열로 변환 후 소수점을 제거하고 정수형으로 변환
            else:
                content_id = ""

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 필요성", ""),
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", ""),
                             content_id])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_specific_diet","disease_name", "synonyms", "importance_of_diet", "actual_diet_therapy", "recommended_food", "caution_food", "other_notes","disease_id"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_specific_diet disease_name             synonyms  \
# 0               후천성면역결핍증식    후천성 면역결핍증                  에이즈
# 1                    후두암식          후두암     후두암의 식사, 암환자의 영양
# 2                     화상식           화상                   화상
# 3                호모시스틴뇨증식      호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4                    협심증식          협심증                  NaN
# ..                    ...          ...                  ...
# 99               갑상선기능저하증     갑상선기능저하증             균형식, 일반식
# 100                 간이식후식     간이식 후 상태           고열량식, 고단백식
# 101                 간성혼수식        간성 뇌증                 간성뇌증
# 102                  간경화식          간경화             간질환, 간경변
# 103                  각기병식          각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                             importance_of_diet_therapy  \
# 0    필요한 영양소를 공급하고 질병이 진행됨에 따라 영양소의 비정상적인 상태와 불내성이 ...
# 1    후두암 진단 이후 치료를 받기위해 충분한 영양공급을 통해 암 치료를 돕고 부작용을 ...
# 2    화상 환자는 대사항진으로 체단백의 이화작용과 요 질소 배설이 증가되며, 단백질과 체...
# 3    호모시스틴 대사에 필요한 효소 결핍으로 메티오닌이 과다생성됨으로써 나타날 수 있는 ...
# 4    협심증은 심장에 산소와 영양을 공급하는 관상동맥이 좁아져 정상적인 혈액공급이 방해받...
# ..                                                 ...
# 99   갑상선기능저하증은 체중증가, 변비, 혈중 콜레스테롤 상승, 철결핍성 빈혈 등의 증상...
# 100  간이식을 받은 환자에게 수술 후 생길 수 있는 부작용과 합병증을 최소화하기 위해 충...
# 101  고단백 식사, 변비, 탈수 등의 원인으로 간성 혼수가 유발될 수 있으므로 환자의 컨...
# 102  간경화 시 식사량 감소, 소화 및 흡수 기능 저하, 영양소 대사 변화, 영양 요구량...
# 103  비타민 B1(티아민) 섭취 부족으로 인해 생기는 질병으로 지나치게 백미 위주의 식사...
#
#                                    actual_diet_therapy  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                       recommended_food  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                           caution_food  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                            other_notes  disease_id
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.     31627.0
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...     31961.0
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...     32321.0
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...     32369.0
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...     32179.0
# ..                                                 ...         ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...     30863.0
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.     31390.0
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.     32092.0
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.     30480.0
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.     31897.0
#
# [104 rows x 9 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # contentId 가져오기
            content_id_tag = disease_soup.find("a", href=lambda href: href and "contentId=" in href)
            if content_id_tag:
                content_id = content_id_tag["href"].split("=")[-1].split('.')[0]
                content_id = int(content_id)  # 문자열로 변환 후 소수점을 제거하고 정수형으로 변환
            else:
                content_id = ""

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", ""),
                             content_id])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_specific_diet","disease_name", "synonyms", "actual_diet_therapy", "recommended_food", "caution_food", "other_notes", "disease_id"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'

# %%
import pandas as pd
df = pd.read_csv('/content/disease_data.csv')
df
# Out:
#     disease_specific_diet disease_name             synonyms  \
# 0               후천성면역결핍증식    후천성 면역결핍증                  에이즈
# 1                    후두암식          후두암     후두암의 식사, 암환자의 영양
# 2                     화상식           화상                   화상
# 3                호모시스틴뇨증식      호모시스틴뇨증     호모시스틴뇨증, 고메티오닌혈증
# 4                    협심증식          협심증                  NaN
# ..                    ...          ...                  ...
# 99               갑상선기능저하증     갑상선기능저하증             균형식, 일반식
# 100                 간이식후식     간이식 후 상태           고열량식, 고단백식
# 101                 간성혼수식        간성 뇌증                 간성뇌증
# 102                  간경화식          간경화             간질환, 간경변
# 103                  각기병식          각기병  티아민 결핍증, 비타민 B1 결핍증
#
#                                    actual_diet_therapy  \
# 0    1. 균형잡힌 식사를 합니다.\r\n2. 단백질 식품을 충분히 섭취합니다.\r\n3...
# 1    암을 치료하는 특별한 식품이나 영양소는 없으며 균형잡힌 식사로 좋은 영양상태를 유지...
# 2    1. 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2. 식사를 규칙...
# 3    1. 메티오닌이 제거된 특수분유(예. 메티오닌 프리 분유, Hominex)와 일반분...
# 4    1. 밥은 현미, 보리 등을 섞은 잡곡밥이 좋으며 기호에 따라 적정량 혼식합니다. ...
# ..                                                 ...
# 99   1. 매끼 골고루 섭취하여 균형적인 식사를 합니다.\r\n2. 정상체중을 유지하도록...
# 100  1. 이식 초기에는 회복을 위해 충분한 에너지, 단백질 반찬을 섭취합니다.\r\n2...
# 101  1. 고기, 생선, 두부, 계란, 콩 등의 단백질 섭취량을 줄입니다. 혼수 정도에 ...
# 102  1. 회복을 위해 충분한 칼로리 섭취가 필요하므로 당질과 지방을 통해 칼로리 섭취를...
# 103  1. 비타민 B1(티아민)이 많은 식품을 섭취합니다.\r\n   (돼지고기나 삼치,...
#
#                                       recommended_food  \
# 0    양질의 살코기, 생선, 두부, 계란 등의 단백질 식품, 신선한 채소류, 과일류, 달...
# 1    현미, 보리, 서리태와 같은 잡곡 및 두류 \r\n파프리카, 당근, 단호박, 양배추...
# 2    곡류(쌀밥, 잡곡밥, 감자, 고구마, 떡 등),육류(살코기), 어류(생선, 조개류 ...
# 3                                 곡류, 채소류, 과일류, 식물성 기름
# 4    신선한 채소를 비롯한 잡곡, 저지방 어육류, 생선, 두부 그리고 제철 과일과 우유 ...
# ..                                                 ...
# 99   - 곡류 및 전분류 (쌀밥, 전곡, 잡곡밥, 국수, 떡, 식빵, 씨리얼, 감자, 고...
# 100  이식 초기 : 신선한 육류(살코기), 생선, 두부, 콩, 우유, 두유, 영양보충음료...
# 101                     밥, 떡, 감자, 고구마 등의 곡류 음식, 과일, 야채
# 102  밥, 떡, 감자, 고구마 등 곡류 음식, 과일, 야채, 단백질 식품(살코기, 생선,...
# 103  돼지고기, 가금류, 계란, 생선, 콩류, 잡곡류, 감자, 아스파라거스, 브로콜리, ...
#
#                                           caution_food  \
# 0    과량의 비타민제 섭취, 사탕, 설탕 등의 과다한 단순당 섭취, 기름진 육류, 기름진...
# 1                              술, 비위생적인 식품, 가공식품, 탄 음식
# 2    단순당(사탕,설탕, 젤리, 물엿), 당분이 첨가된 음료수(콜라,사이다), 통조림 과...
# 3                    콩 및 두부류, 고기, 생선류 등 단백질을 많이 함유한 식품
# 4    고지방 어육류 : 갈비, 삼겹살, 육류의 껍질과 기름, 장어, 햄류\r\n고콜레스테...
# ..                                                 ...
# 99   균형잡힌 식사 시 체내 필요한 충분한 양의 요오드를 함유하고 있으므로 요오드 성분을...
# 100  이식 후 안정기 : 라면, 자장면, 삼겹살, 베이컨, 장아찌, 젓갈, 생선알, 케이...
# 101                   고기, 생선, 두부, 콩, 계란, 유제품 등의 고단백 식품
# 102  절인 음식(김치, 젓갈, 장아찌, 자반류, 마른 반찬, 햄, 소시지 등), 국 국물...
# 103                        정제된 쌀(백미),주류(소주, 맥주, 막걸리 등)
#
#                                            other_notes  disease_id
# 0            흡수불량이 의심되는 경우에는 저지방식과 중쇄중성지방을 이용할 수 있습니다.     31627.0
# 1    환자의 질환과 치료상태에 따라 식사요법의 원칙이 달라질수 있으므로 의료진, 영양전문...     31961.0
# 2    1. 식사섭취량이 충분치 않을 경우 필요시 칼슘, 비타민E, 비타민A, 아연 등을 ...     32321.0
# 3    처방된 분유를 전량 먹이지 못하고 지속적으로 남기게 되면 필수영양소 결핍, 성장지연...     32369.0
# 4    소량씩 자주 먹습니다.\r\n상태에 따라 포화지방산, 콜레스테롤, 염분 섭취를 제한...     32179.0
# ..                                                 ...         ...
# 99   요오드가 부족하거나 지나치게 많이 섭취하는 것은 갑상선 기능에 좋지 않은 영향을 줍...     30863.0
# 100      고칼륨혈증 발생 시 일시적으로 칼륨 함량 높은 음식의 제한이 필요할 수 있습니다.     31390.0
# 101        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.     32092.0
# 102        녹즙 등 고농축 음식이나 민간요법은 간기능을 약화시킬 수 있으므로 주의합니다.     30480.0
# 103               장시간 가열 조리하면 비타민으로서의 기능을 잃게 되니 주의합니다.     31897.0
#
# [104 rows x 8 columns]

# %%
import requests
from bs4 import BeautifulSoup
import csv

# 결과를 담을 빈 리스트 생성
data = []

# 페이지 인덱스를 변경하며 각 페이지의 URL에 접근하여 데이터 추출
for page_index in range(1, 12):  # 예시로 10 페이지까지만 순회
    url = f"https://www.amc.seoul.kr/asan/healthinfo/mealtherapy/mealTherapyList.do?pageIndex={page_index}&searchCondition=&searchKeyword=&mtId="
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")

    # 질병명과 링크 가져오기
    for disease in soup.find_all("dt"):
        disease_name_tag = disease.find("a", class_="txtellipsis")
        if disease_name_tag:
            disease_name = disease_name_tag.text.strip()
            disease_link = "https://www.amc.seoul.kr" + disease_name_tag["href"]

            # 상세 페이지의 HTML 가져오기
            disease_response = requests.get(disease_link).text
            disease_soup = BeautifulSoup(disease_response, "html.parser")

            # contentId 가져오기
            content_id_tag = disease_soup.find("a", href=lambda href: href and "contentId=" in href)
            if content_id_tag:
                content_id = content_id_tag["href"].split("=")[-1].split('.')[0]
                content_id = int(content_id)  # 문자열로 변환 후 소수점을 제거하고 정수형으로 변환
            else:
                content_id = ""

            # 관련 질환과 동의어 가져오기
            related_conditions_tag = disease_soup.find("div", class_="contBox")
            related_conditions_text = ""
            synonyms_text = ""
            if related_conditions_tag:
                related_conditions_tag = related_conditions_tag.find_all("dd")
                if len(related_conditions_tag) >= 2:
                    related_conditions_text = related_conditions_tag[0].text.strip()
                    synonyms_text = related_conditions_tag[1].text.strip()
                elif len(related_conditions_tag) == 1:
                    related_conditions_text = related_conditions_tag[0].text.strip()

            # 본문 내용 가져오기
            diet_therapy_tag = disease_soup.find("dl", class_="descDl")
            if diet_therapy_tag:
                # 각 항목을 딕셔너리로 저장
                diet_therapy_dict = {}
                for item in diet_therapy_tag.find_all(["dt", "dd"]):
                    if item.name == "dt":
                        current_key = item.text.strip()
                    elif item.name == "dd" and current_key:
                        diet_therapy_dict[current_key] = item.text.strip()

                # 결과를 리스트에 추가
                data.append([disease_name, related_conditions_text, synonyms_text,
                             diet_therapy_dict.get("식사요법의 실제", ""),
                             diet_therapy_dict.get("권장 식품", ""),
                             diet_therapy_dict.get("주의 식품", ""),
                             diet_therapy_dict.get("그 외 주의사항", ""),
                             content_id])

# CSV 파일에 결과 저장
with open("disease_data.csv", "w", encoding="utf-8-sig", newline="") as csvfile:
    writer = csv.writer(csvfile)

    # 칼럼 헤더 작성 (영어로 변경)
    headers = ["disease_specific_diet","disease_name", "synonyms", "diet_therapy", "recommended_food", "caution_food", "other_notes", "disease_id"]
    writer.writerow(headers)

    # 각 행 작성
    for row in data:
        writer.writerow(row)

print("Data has been saved to 'disease_data.csv'")
# Out:
# Data has been saved to 'disease_data.csv'
